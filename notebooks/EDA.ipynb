# %%
import pandas as pd

# %%
df = pd.read_csv("loan_approval_dataset.csv")

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
# Columns contains extra spaces

df.columns.tolist()
# Out:
# ['loan_id',
#  ' no_of_dependents',
#  ' education',
#  ' self_employed',
#  ' income_annum',
#  ' loan_amount',
#  ' loan_term',
#  ' cibil_score',
#  ' residential_assets_value',
#  ' commercial_assets_value',
#  ' luxury_assets_value',
#  ' bank_asset_value',
#  ' loan_status']

# %%
# Removing extra spaces from all columns

df.columns = df.columns.str.strip()

# %%
df.columns.tolist()
# Out:
# ['loan_id',
#  'no_of_dependents',
#  'education',
#  'self_employed',
#  'income_annum',
#  'loan_amount',
#  'loan_term',
#  'cibil_score',
#  'residential_assets_value',
#  'commercial_assets_value',
#  'luxury_assets_value',
#  'bank_asset_value',
#  'loan_status']

# %%
df['education'].value_counts()
# Out:
# education
# Graduate        2144
# Not Graduate    2125
# Name: count, dtype: int64

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# loan_id                     0
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
df.drop(['education', 'loan_status', 'self_employed'], axis=1, inplace=True)

# %%
df.head(20)
# Out:
#     loan_id  no_of_dependents  income_annum  loan_amount  loan_term  \
# 0         1                 2       9600000     29900000         12
# 1         2                 0       4100000     12200000          8
# 2         3                 3       9100000     29700000         20
# 3         4                 3       8200000     30700000          8
# 4         5                 5       9800000     24200000         20
# 5         6                 0       4800000     13500000         10
# 6         7                 5       8700000     33000000          4
# 7         8                 2       5700000     15000000         20
# 8         9                 0        800000      2200000         20
# 9        10                 5       1100000      4300000         10
# 10       11                 4       2900000     11200000          2
# 11       12                 2       6700000     22700000         18
# 12       13                 3       5000000     11600000         16
# ...

# %%
df.dtypes
# Out:
# loan_id                     int64
# no_of_dependents            int64
# income_annum                int64
# loan_amount                 int64
# loan_term                   int64
# cibil_score                 int64
# residential_assets_value    int64
# commercial_assets_value     int64
# luxury_assets_value         int64
# bank_asset_value            int64
# education_label             int64
# loan_status_label           int64
# self_employed_label         int64
# dtype: object

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #  Visualization 1

# %%
plt.scatter(df['income_annum'], df['loan_amount'], color='orange')
plt.xlabel("Annual Income")
plt.ylabel("Loan amount")
plt.title("Annual income vs laon amount")
plt.show()

# %% [markdown]
# # Visualization 2

# %%
plt.bar(df['cibil_score'], df['loan_status_label'], color='orange')
plt.xlabel("Cibil Score")
plt.ylabel("Loan Status")
plt.title("Cibil Score vs Loan Status")
plt.show()

# %%
df.describe()
# Out:
#            loan_id  no_of_dependents  income_annum   loan_amount    loan_term  \
# count  4269.000000       4269.000000  4.269000e+03  4.269000e+03  4269.000000
# mean   2135.000000          2.498712  5.059124e+06  1.513345e+07    10.900445
# std    1232.498479          1.695910  2.806840e+06  9.043363e+06     5.709187
# min       1.000000          0.000000  2.000000e+05  3.000000e+05     2.000000
# 25%    1068.000000          1.000000  2.700000e+06  7.700000e+06     6.000000
# 50%    2135.000000          3.000000  5.100000e+06  1.450000e+07    10.000000
# 75%    3202.000000          4.000000  7.500000e+06  2.150000e+07    16.000000
# max    4269.000000          5.000000  9.900000e+06  3.950000e+07    20.000000
#
#        cibil_score  residential_assets_value  commercial_assets_value  \
# count  4269.000000              4.269000e+03             4.269000e+03
# mean    599.936051              7.472617e+06             4.973155e+06
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4269 non-null   object
#  3   self_employed             4269 non-null   object
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.dtypes
# Out:
# loan_id                      int64
# no_of_dependents             int64
# education                   object
# self_employed               object
# income_annum                 int64
# loan_amount                  int64
# loan_term                    int64
# cibil_score                  int64
# residential_assets_value     int64
# commercial_assets_value      int64
# luxury_assets_value          int64
# bank_asset_value             int64
# loan_status                 object
# dtype: object

# %%
df.duplicated()   # No duplicate value in this dataset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4264    False
# 4265    False
# 4266    False
# 4267    False
# 4268    False
# Length: 4269, dtype: bool

# %%
df.describe(include='all')  # gives statistical summary including categorical columns
# Out:
#             loan_id  no_of_dependents  education self_employed  income_annum  \
# count   4269.000000       4269.000000       4269          4269  4.269000e+03
# unique          NaN               NaN          2             2           NaN
# top             NaN               NaN   Graduate           Yes           NaN
# freq            NaN               NaN       2144          2150           NaN
# mean    2135.000000          2.498712        NaN           NaN  5.059124e+06
# std     1232.498479          1.695910        NaN           NaN  2.806840e+06
# min        1.000000          0.000000        NaN           NaN  2.000000e+05
# 25%     1068.000000          1.000000        NaN           NaN  2.700000e+06
# 50%     2135.000000          3.000000        NaN           NaN  5.100000e+06
# 75%     3202.000000          4.000000        NaN           NaN  7.500000e+06
# max     4269.000000          5.000000        NaN           NaN  9.900000e+06
#
# ...

# %%
df.nunique()
# Out:
# loan_id                     4269
# no_of_dependents               6
# education                      2
# self_employed                  2
# income_annum                  98
# loan_amount                  378
# loan_term                     10
# cibil_score                  601
# residential_assets_value     278
# commercial_assets_value      188
# luxury_assets_value          379
# bank_asset_value             146
# loan_status                    2
# dtype: int64

# %%
df.to_csv("cleaned_data1.csv")
