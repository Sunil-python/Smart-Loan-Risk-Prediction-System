# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  loan_id  no_of_dependents  income_annum  loan_amount  \
# 0           0        1                 2       9600000     29900000
# 1           1        2                 0       4100000     12200000
# 2           2        3                 3       9100000     29700000
# 3           3        4                 3       8200000     30700000
# 4           4        5                 5       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value  education_label  loan_status_label  \
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    loan_id  no_of_dependents  income_annum  loan_amount  loan_term  \
# 0        1                 2       9600000     29900000         12
# 1        2                 0       4100000     12200000          8
# 2        3                 3       9100000     29700000         20
# 3        4                 3       8200000     30700000          8
# 4        5                 5       9800000     24200000         20
#
#    cibil_score  residential_assets_value  commercial_assets_value  \
# 0          778                   2400000                 17600000
# 1          417                   2700000                  2200000
# 2          506                   7100000                  4500000
# 3          467                  18200000                  3300000
# 4          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value  education_label  loan_status_label  \
# 0             22700000           8000000                0                  0
# ...

# %% [markdown]
# # Splitting into dependent and independent

# %%
X = df[ ['no_of_dependents','income_annum','loan_amount','loan_term','cibil_score','residential_assets_value','commercial_assets_value','luxury_assets_value','bank_asset_value','education_label','self_employed_label']]
y = df['loan_status_label']

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(X,y, test_size=0.2)

# %%
len(train_x),len(train_y)
# Out:
# (3415, 3415)

# %%
len(test_x),len(test_y)
# Out:
# (854, 854)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.accuracy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model.accuracy()
#
# AttributeError: 'LogisticRegression' object has no attribute 'accuracy'
